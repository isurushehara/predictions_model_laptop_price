# %%
# !pip install numpy
# !pip install pandas
# Out:
# Requirement already satisfied: numpy in .\venv\Lib\site-packages (2.4.6)
# Collecting pandas
#   Using cached pandas-3.0.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in .\venv\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\venv\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in .\venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-3.0.3-cp313-cp313-win_amd64.whl (9.8 MB)
# Installing collected packages: pandas
# Successfully installed pandas-3.0.3

# %%
import numpy as np
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/isurushehara/predictions_model_laptop_price/refs/heads/main/src/table.csv"
data = pd.read_csv(url, encoding='latin-1')
data.head()
# Out:
#    laptopID Company   TypeName  Inches                    ScreenResolution  \
# 0         0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1         1   Apple  Ultrabook    13.3                            1440x900
# 2         2      HP   Notebook    15.6                   Full HD 1920x1080
# 3         3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4         4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
data.shape
# Out:
# (1303, 12)

# %%
data.isnull().sum()
# Out:
# laptopID            0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptopID          1303 non-null   int64
#  1   Company           1303 non-null   str
#  2   TypeName          1303 non-null   str
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   str
#  5   Cpu               1303 non-null   str
#  6   Ram               1303 non-null   str
#  7   Memory            1303 non-null   str
#  8   Gpu               1303 non-null   str
#  9   OpSys             1303 non-null   str
#  10  Weight            1303 non-null   str
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), str(9)
# memory usage: 122.3 KB

# %%
data.head(2)
# Out:
#    laptopID Company   TypeName  Inches                    ScreenResolution  \
# 0         0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1         1   Apple  Ultrabook    13.3                            1440x900
#
#                     Cpu  Ram               Memory  \
# 0  Intel Core i5 2.3GHz  8GB            128GB SSD
# 1  Intel Core i5 1.8GHz  8GB  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg  47895.5232

# %%
data['Ram'] = data['Ram'].str.replace('GB', '').astype('int32')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptopID          1303 non-null   int64
#  1   Company           1303 non-null   str
#  2   TypeName          1303 non-null   str
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   str
#  5   Cpu               1303 non-null   str
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   str
#  8   Gpu               1303 non-null   str
#  9   OpSys             1303 non-null   str
#  10  Weight            1303 non-null   float32
#  11  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), int64(1), str(7)
# memory usage: 112.1 KB

# %%
data.head(2)
# Out:
#    laptopID Company   TypeName  Inches                    ScreenResolution  \
# 0         0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1         1   Apple  Ultrabook    13.3                            1440x900
#
#                     Cpu  Ram               Memory  \
# 0  Intel Core i5 2.3GHz    8            128GB SSD
# 1  Intel Core i5 1.8GHz    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg  47895.5232

# %%
data['Weight'] = data['Weight'].str.replace('kg', '').astype('float32')

# %%
data.head(2)
# Out:
#    laptopID Company   TypeName  Inches                    ScreenResolution  \
# 0         0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1         1   Apple  Ultrabook    13.3                            1440x900
#
#                     Cpu  Ram               Memory  \
# 0  Intel Core i5 2.3GHz    8            128GB SSD
# 1  Intel Core i5 1.8GHz    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232

# %%
data.corr()['Price']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 data.corr()['Price']
#
# File D:\OFFICIAL\Programming\ML\Projects\Simple\Laptop price predictor\model\venv\Lib\site-packages\pandas\core\frame.py:13133, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13129         """  # noqa: E501
#   13130         data = self._get_numeric_data() if numeric_only else self
#   13131         cols = data.columns
#   13132         idx = cols.copy()
# > 13133         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13134
#   13135         if method == "pearson":
#   13136             correl = libalgos.nancorr(mat, minp=min_periods)
#
# File D:\OFFICIAL\Programming\ML\Projects\Simple\Laptop price predictor\model\venv\Lib\site-packages\pandas\core\frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2077                [2, 4.5, Timestamp('2000-01-02 00:00:00')]], dtype=object)
#    2078         """
#    2079         if dtype is not None:
#    2080             dtype = np.dtype(dtype)
# -> 2081         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2082         if result.dtype is not dtype:
#    2083             result = np.asarray(result, dtype=dtype)
#    2084
#
# File D:\OFFICIAL\Programming\ML\Projects\Simple\Laptop price predictor\model\venv\Lib\site-packages\pandas\core\internals\managers.py:1872, in BlockManager.as_array(self, dtype, copy, na_value)
#    1870         arr.flags.writeable = False
#    1871 else:
# -> 1872     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1873     # The underlying data was copied within _interleave, so no need
#    1874     # to further copy if copy=True or setting na_value
#    1876 if na_value is lib.no_default:
#
# File D:\OFFICIAL\Programming\ML\Projects\Simple\Laptop price predictor\model\venv\Lib\site-packages\pandas\core\internals\managers.py:1925, in BlockManager._interleave(self, dtype, na_value)
#    1919 rl = blk.mgr_locs
#    1920 if blk.is_extension:
#    1921     # Avoid implicit conversion of extension blocks to object
#    1922
#    1923     # error: Item "ndarray" of "Union[ndarray, ExtensionArray]" has no
#    1924     # attribute "to_numpy"
# -> 1925     arr = blk.values.to_numpy(  # type: ignore[union-attr]
#    1926         dtype=dtype,
#    1927         na_value=na_value,
#    1928     )
#    1929 else:
#    1930     arr = blk.get_values(dtype)
#
# File D:\OFFICIAL\Programming\ML\Projects\Simple\Laptop price predictor\model\venv\Lib\site-packages\pandas\core\arrays\numpy_.py:589, in NumpyExtensionArray.to_numpy(self, dtype, copy, na_value)
#     586         result = result.view()
#     587         result.flags.writeable = False
# --> 589 result = np.asarray(result, dtype=dtype)
#     591 if copy and result is self._ndarray:
#     592     result = result.copy()
#
# ValueError: could not convert string to float: 'Apple'

# %%
data['Company'].value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
def add_company(inpt):
    if inpt == 'Samsung' or inpt == 'Razer' or inpt == 'Mediacom' or inpt == 'Microsoft' or inpt == 'Xiaomi' or inpt == 'Vero' or inpt == 'Chuwi' or inpt == 'Google' or inpt == 'Fujitsu' or inpt == 'LG' or inpt == 'Huawei':
        return 'Other'
    else:
        return inpt

data['Company'] = data['Company'].apply(add_company)

# %%
data['Company'].value_counts()
# Out:
# Company
# Dell       297
# Lenovo     297
# HP         274
# Asus       158
# Acer       103
# MSI         54
# Other       51
# Toshiba     48
# Apple       21
# Name: count, dtype: int64

# %%
data['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: count, dtype: int64

# %%
data['Touchscreen'] = data['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
data['Ips'] = data['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
data.head(2)
# Out:
#    laptopID Company   TypeName  Inches                    ScreenResolution  \
# 0         0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1         1   Apple  Ultrabook    13.3                            1440x900
#
#                     Cpu  Ram               Memory  \
# 0  Intel Core i5 2.3GHz    8            128GB SSD
# 1  Intel Core i5 1.8GHz    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232            0    0

# %%
data['cpu_name'] = data['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
data.head(2)
# Out:
#    laptopID Company   TypeName  Inches                    ScreenResolution  \
# 0         0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1         1   Apple  Ultrabook    13.3                            1440x900
#
#                     Cpu  Ram               Memory  \
# 0  Intel Core i5 2.3GHz    8            128GB SSD
# 1  Intel Core i5 1.8GHz    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232            0    0
#
#         cpu_name
# 0  Intel Core i5
# 1  Intel Core i5

# %%
data['cpu_name'].value_counts()
# Out:
# cpu_name
# Intel Core i7               527
# Intel Core i5               423
# Intel Core i3               136
# Intel Celeron Dual           80
# Intel Pentium Quad           27
# Intel Core M                 19
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# Intel Celeron Quad            8
# AMD A12-Series 9720P          7
# Intel Atom x5-Z8350           5
# Intel Atom x5-Z8550           4
# AMD A8-Series 7410            4
# AMD Ryzen 1700                3
# Intel Pentium Dual            3
# AMD A9-Series 9410            3
# AMD E-Series E2-9000e         2
# Intel Xeon E3-1505M           2
# AMD A10-Series A10-9620P      2
# AMD A6-Series A6-9220         2
# AMD A10-Series 9600P          2
# AMD A10-Series 9620P          2
# AMD E-Series 7110             2
# AMD A9-Series A9-9420         2
# Intel Xeon E3-1535M           2
# Intel Atom X5-Z8350           2
# Intel Atom x5-Z8300           1
# AMD E-Series E2-6110          1
# AMD FX 9830P                  1
# AMD E-Series 6110             1
# AMD E-Series 9000e            1
# AMD Ryzen 1600                1
# AMD E-Series E2-9000          1
# AMD A6-Series 7310            1
# Intel Atom Z8350              1
# AMD A12-Series 9700P          1
# AMD A4-Series 7210            1
# AMD FX 8800P                  1
# Samsung Cortex A72&A53        1
# AMD E-Series 9000             1
# Name: count, dtype: int64

# %%
def set_processor(name):
    if name == 'Intel Core i7' or name == 'Intel Core i5' or name == 'Intel Core i3':
        return name
    else:
        if name.split()[0] == 'AMD':
            return 'AMD'
        else:
            return "Other'

data['cpu_name'] = data['cpu_name'].apply(set_processor)
# Out:
#   Cell In[32], line 8
#     return "Other'
#            ^
# SyntaxError: unterminated string literal (detected at line 8)

# %%
def set_processor(name):
    if name == 'Intel Core i7' or name == 'Intel Core i5' or name == 'Intel Core i3':
        return name
    else:
        if name.split()[0] == 'AMD':
            return 'AMD'
        else:
            return 'Other'

data['cpu_name'] = data['cpu_name'].apply(set_processor)

# %%
data['cpu_name'].value_counts()
# Out:
# cpu_name
# Intel Core i7    527
# Intel Core i5    423
# Other            155
# Intel Core i3    136
# AMD               62
# Name: count, dtype: int64

# %%
data.head(5)
# Out:
#    laptopID Company   TypeName  Inches                    ScreenResolution  \
# 0         0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1         1   Apple  Ultrabook    13.3                            1440x900
# 2         2      HP   Notebook    15.6                   Full HD 1920x1080
# 3         3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4         4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#         cpu_name
# 0  Intel Core i5
# 1  Intel Core i5
# 2  Intel Core i5
# 3  Intel Core i7
# 4  Intel Core i5

# %%
data['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 256GB SSD +  256GB SSD             2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 1TB SSD +  1TB HDD                 2
# 512GB Flash Storage                2
# 64GB SSD                           1
# 512GB SSD +  512GB SSD             1
# 512GB SSD +  256GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
data['SSD'] = 0
data['HDD'] = 0
data['Hybrid'] = 0
data['Flash_Storage'] = 0

# %%
import re

def process_memory(memory):

    parts = memory.split("+")

    ssd = 0
    hdd = 0
    hybrid = 0
    flash = 0

    for part in parts:

        part = part.strip()

        # Extract the numeric value
        size = re.findall(r'(\d+\.?\d*)', part)

        if len(size) == 0:
            continue

        size = float(size[0])

        # Convert TB to GB
        if size <= 2:
            size *= 1024

        if 'SSD' in part:
            ssd += size

        elif 'HDD' in part:
            hdd += size

        elif 'Hybrid' in part:
            hybrid += size

        elif 'Flash Storage' in part:
            flash += size

    return pd.Series([ssd, hdd, hybrid, flash])

# %%
data[['SSD','HDD','Hybrid','Flash_Storage']] = data['Memory'].apply(process_memory)

# %%
data.head(100)
# Out:
#     laptopID Company            TypeName  Inches  \
# 0          0   Apple           Ultrabook    13.3
# 1          1   Apple           Ultrabook    13.3
# 2          2      HP            Notebook    15.6
# 3          3   Apple           Ultrabook    15.4
# 4          4   Apple           Ultrabook    13.3
# ..       ...     ...                 ...     ...
# 95        95    Acer  2 in 1 Convertible    13.3
# 96        96    Dell            Notebook    15.6
# 97        97    Dell            Notebook    15.6
# 98        98    Asus            Notebook    15.6
# 99        99      HP              Gaming    15.6
#
#                              ScreenResolution                          Cpu  \
# 0          IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz
# 1                                    1440x900         Intel Core i5 1.8GHz
# 2                           Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 3          IPS Panel Retina Display 2880x1800         Intel Core i7 2.7GHz
# 4          IPS Panel Retina Display 2560x1600         Intel Core i5 3.1GHz
# ..                                        ...                          ...
# 95  IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i5 8250U 1.6GHz
# 96                          Full HD 1920x1080   Intel Core i7 7500U 2.7GHz
# 97                          Full HD 1920x1080     Intel Core i3 6006U 2GHz
# 98                          Full HD 1920x1080   Intel Core i3 7100U 2.4GHz
# 99                IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
#
#     Ram                Memory                           Gpu       OpSys  \
# 0     8             128GB SSD  Intel Iris Plus Graphics 640       macOS
# 1     8   128GB Flash Storage        Intel HD Graphics 6000       macOS
# 2     8             256GB SSD         Intel HD Graphics 620       No OS
# 3    16             512GB SSD            AMD Radeon Pro 455       macOS
# 4     8             256GB SSD  Intel Iris Plus Graphics 650       macOS
# ..  ...                   ...                           ...         ...
# 95    8             256GB SSD        Intel UHD Graphics 620  Windows 10
# 96    8               1TB HDD            AMD Radeon R5 M430       Linux
# 97    4             256GB SSD            AMD Radeon R5 M430       Linux
# 98    6             256GB SSD           Nvidia GeForce 920M  Windows 10
# 99   12  128GB SSD +  1TB HDD       Nvidia GeForce GTX 1050  Windows 10
#
#     Weight        Price  Touchscreen  Ips       cpu_name    SSD     HDD  \
# 0     1.37   71378.6832            0    1  Intel Core i5  128.0     0.0
# 1     1.34   47895.5232            0    0  Intel Core i5    0.0     0.0
# 2     1.86   30636.0000            0    0  Intel Core i5  256.0     0.0
# 3     1.83  135195.3360            0    1  Intel Core i7  512.0     0.0
# 4     1.37   96095.8080            0    1  Intel Core i5  256.0     0.0
# ..     ...          ...          ...  ...            ...    ...     ...
# 95    1.50   45128.1600            1    1  Intel Core i5  256.0     0.0
# 96    2.20   31962.6720            0    0  Intel Core i7    0.0  1024.0
# 97    2.20   25840.8000            0    0  Intel Core i3  256.0     0.0
# 98    2.00   30742.5600            0    0  Intel Core i3  256.0     0.0
# 99    2.62   66546.7200            0    1  Intel Core i7  128.0  1024.0
#
#     Hybrid  Flash_Storage
# 0      0.0            0.0
# 1      0.0          128.0
# 2      0.0            0.0
# 3      0.0            0.0
# 4      0.0            0.0
# ..     ...            ...
# 95     0.0            0.0
# 96     0.0            0.0
# 97     0.0            0.0
# 98     0.0            0.0
# 99     0.0            0.0
#
# [100 rows x 19 columns]

# %%
data['gpu_name'] = data['Gpu'].apply(lambda x:" ".join(x.split()[0:1]))

# %%
data.head(5)
# Out:
#    laptopID Company   TypeName  Inches                    ScreenResolution  \
# 0         0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1         1   Apple  Ultrabook    13.3                            1440x900
# 2         2      HP   Notebook    15.6                   Full HD 1920x1080
# 3         3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4         4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#         cpu_name    SSD  HDD  Hybrid  Flash_Storage gpu_name
# 0  Intel Core i5  128.0  0.0     0.0            0.0    Intel
# 1  Intel Core i5    0.0  0.0     0.0          128.0    Intel
# 2  Intel Core i5  256.0  0.0     0.0            0.0    Intel
# 3  Intel Core i7  512.0  0.0     0.0            0.0      AMD
# 4  Intel Core i5  256.0  0.0     0.0            0.0    Intel

# %%
data['gpu_name'].value_counts()
# Out:
# gpu_name
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
data = data[data['gpu_name'] != 'ARM']

# %%
def set_os(inpt):
    if inpt == 'Windows 10' or inpt == 'Windows 7' or inpt == 'Windows 10 S':
        return 'Windows'
    elif inpt == 'macOS' or inpt == 'Mac OS X':
        return 'Mac'
    elif inpt == 'Linux':
        return inpt
    else:
        return 'Other'

data['OpSys'] = data['OpSys'].apply(set_os)

# %%
data.head(5)
# Out:
#    laptopID Company   TypeName  Inches                    ScreenResolution  \
# 0         0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1         1   Apple  Ultrabook    13.3                            1440x900
# 2         2      HP   Notebook    15.6                   Full HD 1920x1080
# 3         3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4         4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640    Mac    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000    Mac    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  Other    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455    Mac    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650    Mac    1.37   96095.8080            0    1
#
#         cpu_name    SSD  HDD  Hybrid  Flash_Storage gpu_name
# 0  Intel Core i5  128.0  0.0     0.0            0.0    Intel
# 1  Intel Core i5    0.0  0.0     0.0          128.0    Intel
# 2  Intel Core i5  256.0  0.0     0.0            0.0    Intel
# 3  Intel Core i7  512.0  0.0     0.0            0.0      AMD
# 4  Intel Core i5  256.0  0.0     0.0            0.0    Intel

# %%
data = data.drop(columns=['Memory'])

# %%
data.head(5)
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8    Mac    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8    Mac    1.34   47895.5232            0    0
# 2      HP   Notebook    8  Other    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16    Mac    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8    Mac    1.37   96095.8080            0    1
#
#         cpu_name    SSD  HDD  Hybrid  Flash_Storage gpu_name
# 0  Intel Core i5  128.0  0.0     0.0            0.0    Intel
# 1  Intel Core i5    0.0  0.0     0.0          128.0    Intel
# 2  Intel Core i5  256.0  0.0     0.0            0.0    Intel
# 3  Intel Core i7  512.0  0.0     0.0            0.0      AMD
# 4  Intel Core i5  256.0  0.0     0.0            0.0    Intel

# %%
data = pd.get_dummies(data)

# %%
data.head(5)
# Out:
#    Ram  Weight        Price  Touchscreen  Ips    SSD  HDD  Hybrid  \
# 0    8    1.37   71378.6832            0    1  128.0  0.0     0.0
# 1    8    1.34   47895.5232            0    0    0.0  0.0     0.0
# 2    8    1.86   30636.0000            0    0  256.0  0.0     0.0
# 3   16    1.83  135195.3360            0    1  512.0  0.0     0.0
# 4    8    1.37   96095.8080            0    1  256.0  0.0     0.0
#
#    Flash_Storage  Company_Acer  ...  OpSys_Other  OpSys_Windows  cpu_name_AMD  \
# 0            0.0         False  ...        False          False         False
# 1          128.0         False  ...        False          False         False
# 2            0.0         False  ...         True          False         False
# 3            0.0         False  ...        False          False         False
# 4            0.0         False  ...        False          False         False
#
#    cpu_name_Intel Core i3  cpu_name_Intel Core i5  cpu_name_Intel Core i7  \
# 0                   False                    True                   False
# 1                   False                    True                   False
# 2                   False                    True                   False
# 3                   False                   False                    True
# 4                   False                    True                   False
#
#    cpu_name_Other  gpu_name_AMD  gpu_name_Intel  gpu_name_Nvidia
# 0           False         False            True            False
# 1           False         False            True            False
# 2           False         False            True            False
# 3           False          True           False            False
# 4           False         False            True            False
#
# [5 rows x 36 columns]

# %%
data.shape
# Out:
# (1302, 36)

# %%
X = data.drop('Price', axis=1)
y = data['Price']

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.9.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in .\venv\Lib\site-packages (from scikit-learn) (2.4.6)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Using cached scipy-1.17.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.4.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn)
#   Downloading narwhals-2.22.1-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.9.0-cp313-cp313-win_amd64.whl (8.2 MB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading narwhals-2.22.1-py3-none-any.whl (454 kB)
# Using cached scipy-1.17.1-cp313-cp313-win_amd64.whl (36.5 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, narwhals, joblib, scikit-learn
#
#    ---------------------------------------- 0/5 [threadpoolctl]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ------------------------ --------------- 3/5 [joblib]
#    ------------------------ --------------- 3/5 [joblib]
#    ------------------------ --------------- 3/5 [joblib]
#    ------------------------ --------------- 3/5 [joblib]
#    ------------------------ --------------- 3/5 [joblib]
#    ------------------------ --------------- 3/5 [joblib]
#    ------------------------ --------------- 3/5 [joblib]
#    ------------------------ --------------- 3/5 [joblib]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    ---------------------------------------- 5/5 [scikit-learn]
#
# Successfully installed joblib-1.5.3 narwhals-2.22.1 scikit-learn-1.9.0 scipy-1.17.1 threadpoolctl-3.6.0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
X_train.shape, X_test.shape
# Out:
# ((976, 35), (326, 35))

# %%
def model_acc(model):
    model.fit(X_train, y_train)
    acc = model.score(X_test, y_test)
    print(str(model)+ '--> ' +str(acc))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
model_acc(lr)

from sklearn.linear_model import Lasso
lasso = Lasso()
model_acc(lasso)

from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
model_acc(dt)

from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
model_acc(rf)
# Out:
# LinearRegression()--> 0.7327228447415111
# Lasso()--> 0.7327916140512334
# DecisionTreeRegressor()--> 0.5914318055356195
# D:\OFFICIAL\Programming\ML\Projects\Simple\Laptop price predictor\model\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.824754e+10, tolerance: 1.388e+08
#   model = cd_fast.enet_coordinate_descent(
# RandomForestRegressor()--> 0.8066951038035105

# %%
from sklearn.model_selection import GridSearchCV

parameters = {'n_estimators': [10, 50, 100],
'criterion':['squared_error', 'absolute_error', 'poisson']}

grid_obj = GridSearchCV(estimator=rf, param_grid=parameters)

grid_fit = grid_obj.fit(X_train, y_train)

best_model = grid_fit.best_estimator_
best_model
# Out:
# RandomForestRegressor()

# %%
best_model.score(X_test, y_test)
# Out:
# 0.8136527081642111

# %%
import pickle
with open('predictor.pickle','wb') as file:
    pickle.dump(best_model, file)

# %%
X_train.columns
# Out:
# Index(['Ram', 'Weight', 'Touchscreen', 'Ips', 'SSD', 'HDD', 'Hybrid',
#        'Flash_Storage', 'Company_Acer', 'Company_Apple', 'Company_Asus',
#        'Company_Dell', 'Company_HP', 'Company_Lenovo', 'Company_MSI',
#        'Company_Other', 'Company_Toshiba', 'TypeName_2 in 1 Convertible',
#        'TypeName_Gaming', 'TypeName_Netbook', 'TypeName_Notebook',
#        'TypeName_Ultrabook', 'TypeName_Workstation', 'OpSys_Linux',
#        'OpSys_Mac', 'OpSys_Other', 'OpSys_Windows', 'cpu_name_AMD',
#        'cpu_name_Intel Core i3', 'cpu_name_Intel Core i5',
#        'cpu_name_Intel Core i7', 'cpu_name_Other', 'gpu_name_AMD',
#        'gpu_name_Intel', 'gpu_name_Nvidia'],
#       dtype='str')

# %%
best_model.predict([[
    16,     # Ram
    1.5,    # Weight
    0,      # Touchscreen
    1,      # Ips
    512,    # SSD
    0,      # HDD
    0,      # Hybrid
    0,      # Flash_Storage

    # Company
    0,      # Company_Acer
    1,      # Company_Apple
    0,      # Company_Asus
    0,      # Company_Dell
    0,      # Company_HP
    0,      # Company_Lenovo
    0,      # Company_MSI
    0,      # Company_Other
    0,      # Company_Toshiba

    # TypeName
    0,      # 2 in 1 Convertible
    0,      # Gaming
    0,      # Netbook
    0,      # Notebook
    1,      # Ultrabook
    0,      # Workstation

    # OpSys
    0,      # Linux
    1,      # Mac
    0,      # Other
    0,      # Windows

    # CPU
    0,      # AMD
    0,      # Intel Core i3
    0,      # Intel Core i5
    1,      # Intel Core i7
    0,      # Other

    # GPU
    0,      # AMD
    1,      # Intel
    0       # Nvidia
]])
# Out:
# D:\OFFICIAL\Programming\ML\Projects\Simple\Laptop price predictor\model\venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([105716.891952])

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
data.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data.show()
#
# NameError: name 'data' is not defined

# %%
data.head(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data.head(100)
#
# NameError: name 'data' is not defined

# %%
data.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data.head(5)
#
# NameError: name 'data' is not defined
